# %% [markdown]
# First of all we are going to load our CSVs.
# The goal is try to predict the Iberdrola stock price, so I've loaded data from values I thing are related with the Iberdrola stock price, like the eur_usd, eur_gbp, oil_price, ibex35 and other competitors

# %% [markdown]
# Imports

# %%
import numpy as np
from matplotlib import pyplot
from datetime import date as dt
from datetime import timedelta
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import BatchNormalization
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.optimizers import RMSprop
from keras.regularizers import l2

# %% [markdown]
# Now import all the csvs

# %%
#groups = ["iberdrola", "ibex", "oil", "gas_natural", "endesa", "usd", "gbp"]
#groups = ["iberdrola", "ibex", "oil", "usd", "gbp"]
groups = ["iberdrola", "ibex", "oil"]
data = {}

for x in groups:
    data[x] = np.genfromtxt('csvs/csv/%s.csv'%x, delimiter=',', skip_header=1)

# %%
#day,month,year,opening_value,close_value,min_value,max_value,volume
data["iberdrola"][0]
# Out:
# array([1.500000e+01, 6.000000e+00, 2.018000e+03, 6.666000e+00,
#        6.712000e+00, 6.612000e+00, 6.742000e+00, 3.869992e+07])

# %% [markdown]
# Order the input putting the dates in format year-month-day

# %%
for group in groups:
    data[group][:,[0, 2]] = data[group][:,[2, 0]]
    
data["iberdrola"][0]
# Out:
# array([2.018000e+03, 6.000000e+00, 1.500000e+01, 6.666000e+00,
#        6.712000e+00, 6.612000e+00, 6.742000e+00, 3.869992e+07])

# %% [markdown]
# See the graphics of the data we imported from the csv from year 2005

# %%
# plot the close value for each date
def to_time(time_array):
    return dt(day = int(round(time_array[2])), month = int(round(time_array[1])), year = int(round(time_array[0])))

pyplot.figure()
i = 1
for group in groups:
    group_data = data[group]
    print(np.max(group_data[:,4]))
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(list(map(to_time, group_data[:,0:3])), group_data[:,4])
    pyplot.title(group, y=0.5, loc='right')
    i += 1
pyplot.show()
# Out:
# 7.501
# 15945.7
# 1616.0

# %% [markdown]
# We see that we have some strange data in the oil and gbp plots (possible cause bad data retrieved from external servers), so remove this outliers to have a nice plot and trustable values

# %%
def remove_outliers(group_data, outlierConstant):
    closed_values = group_data[:,4]
    upper_quartile = np.percentile(closed_values, 75)
    lower_quartile = np.percentile(closed_values, 25)
    IQR = (upper_quartile - lower_quartile) * outlierConstant
    quartile_set = (lower_quartile - IQR, upper_quartile + IQR)
    mask = np.logical_and(group_data[:,4] >= quartile_set[0],group_data[:,4] <= quartile_set[1])
    result_list = group_data[mask,:]
    return result_list

clean_dataset = {}
for group in groups:
    group_data = data[group]
    without_outliers = remove_outliers(group_data, 3.5)
    total_removed = len(group_data) - len(without_outliers)
    print("Found %d outliers for group: %s" % (total_removed, group))
    clean_dataset[group] = without_outliers
# Out:
# Found 0 outliers for group: iberdrola
# Found 0 outliers for group: ibex
# Found 3 outliers for group: oil

# %% [markdown]
# Now our dataset (clean_dataset) is clean and we can use it as input in our LTSM:

# %%
pyplot.figure()
i = 1
for group in groups:
    group_data = clean_dataset[group]
    print(np.max(group_data[:,4]))
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(list(map(to_time, group_data[:,0:3])), group_data[:,4])
    pyplot.title(group, y=0.5, loc='right')
    i += 1
pyplot.show()
# Out:
# 7.501
# 15945.7
# 145.15

# %% [markdown]
# Now we are going to unify all our data in the same row. For that, we are going to build a csv with the following columns:
#
# day, month, year, [opening, close, min, max, volume]+
#
#  (but volume will not be available in currencies or oil)
#
#  But first get the common dates between all our datasets, to build this big csv

# %%
all_dates = []
group_selected = None
min_length_found = -1
dates_converted_by_group = {}

#TODO vectorize
#Get all dates in our dataset
for group in groups:
    dates_groups = clean_dataset[group][:,0:3]
    converted_dates = []
    for date in dates_groups:
        parsed_date = to_time(date)
        converted_dates.append(parsed_date)
        if parsed_date not in all_dates:
            all_dates.append(parsed_date)
    
    dates_converted_by_group[group] = converted_dates
            
print("Found %d different dates" % len(all_dates))
print("Example: %s" % all_dates[100])
# Out:
# Found 3355 different dates
# Example: 2018-01-23

# %% [markdown]
# Now get only the shared dates between all the datasets

# %%
#TODO: Vectorized
filtered_dates = []

for date in all_dates:
    in_all_groups = True
    for group in groups:
        in_all_groups = in_all_groups and date in dates_converted_by_group[group]
    if in_all_groups:
        filtered_dates.append(date)
        
print("Found %d common dates" % len(filtered_dates))
print("Example: %s" % filtered_dates[100])
# Out:
# Found 2669 common dates
# Example: 2018-01-17

# %% [markdown]
# Now, create a dictionary by time with the data from all the groups

# %%
#Initialize dictionary
final_dict = {}

for date in filtered_dates:
    final_dict[date]={}


for group in groups:
    group_data = clean_dataset[group]
    for row in group_data:
        date = to_time(row)
        if date in filtered_dates:
            data_array = []
            #if group in ["oil", "gbp", "usd"]:
            data_array =  [row[4]] #Put just close_value
            #else:
            #    data_array = row[3:]
            final_dict[date][group] = data_array
        
print("Length of dataset: %d" % len(final_dict))
print("Example : %s" % final_dict[filtered_dates[100]])
# Out:
# Length of dataset: 2669
# Example : {'oil': [69.0], 'iberdrola': [6.706], 'ibex': [10474.6]}

# %% [markdown]
# Now convert it to a final numpy matrix:

# %%
final_array = np.zeros((len(final_dict), 3+len(groups)*1))

i = 0

for date in sorted(final_dict.keys()):
    
    data_array = [date.year, date.month, date.day]
    
    for group in groups:
        row = final_dict[date][group]
        data_array = np.concatenate((data_array, row))

    final_array[i, :] = data_array
    i = i + 1
    
print("Length of dataset: %d" % len(final_array))
print("Example : %s" % final_array[0])
#day,month,year,[(opening_value,close_value,min_value,max_value,volume)+
# Out:
# Length of dataset: 2669
# Example : [2.00700e+03 5.00000e+00 8.00000e+00 5.62300e+00 1.45567e+04 6.35600e+01]

# %%
def print_with_format(row):
    headers = ["year","month","day"]
    for group in groups:
        for x in ["opening_value","close_value","min_value","max_value","volume"]:
            if group in ["oil","usd","gbp"]:
                if x is not "volume":
                    headers.append("%s_%s" % (group,x))
            else:
                headers.append("%s_%s" % (group,x))
            
    print("Row:")
    for header,data in zip(headers,row):
        print("%s:\t%s" % (header, data))
        
print_with_format(final_array[0])
# Out:
# Row:
# year:	2007.0
# month:	5.0
# day:	8.0
# iberdrola_opening_value:	5.623
# iberdrola_close_value:	14556.7
# iberdrola_min_value:	63.56

# %% [markdown]
# As you see our array is ordered by date:

# %%
print("First three rows: %s %s %s" % (to_time(final_array[0]), to_time(final_array[1]), to_time(final_array[2])) )
print("Last three rows: %s %s %s" % (to_time(final_array[2495]), to_time(final_array[2496]), to_time(final_array[2497])) )
# Out:
# First three rows: 2007-05-08 2007-05-09 2007-05-10
# Last three rows: 2017-09-29 2017-10-02 2017-10-03

# %% [markdown]
# # Neural network
#
# Now we are going to split our dataset in training set, dev set, and test set to check that all is working at should.
#
# Because we want to predict what will happen knowing the 100 days before, we are going to package in 100 rows packages all the rows, and setting the next day as expected prediction
#
# So we have to:
# - Create packages with 100 days
# - Generate an expected output for each of this packages (will be the first row in the next package)
# - Normalize all the inputs
# - Build the neural network

# %% [markdown]
# Normalize the final_array

# %%
mean = final_array.mean(axis = 0)
std = final_array.std(axis = 0)
normalized = (final_array - mean) / std

# %% [markdown]
# Generate the 100-day packages:

# %%
package_size = 100
m = final_array.shape[0]
expected_m = m - package_size
number_features = normalized.shape[1]

X = np.zeros((expected_m, package_size, number_features))
Y = np.zeros((expected_m, number_features - 3))

for i in range(0,expected_m):
    package = normalized[ i : i + package_size ]
    #Remove dates because I think is predicting bad the problem 
    expected_output = normalized[ i + package_size][3:]
    X[i] = package
    Y[i] = expected_output

print("X shape: %s - %s - %s" % X.shape)
print("Y shape: %s - %s" % Y.shape)
print("First package: %s" % X[0])
print("Last package: %s" % X[expected_m - 1])

print("First expected output %s" % Y[0])
print("Last expected output %s" % Y[expected_m -1])
# Out:
# X shape: 2569 - 100 - 6
# Y shape: 2569 - 3
# First package: [[-1.64447557 -0.43592758 -0.88243766  0.69159546  2.34411262 -0.70075565]
#  [-1.64447557 -0.43592758 -0.76778907  0.6705526   2.37192596 -0.70678396]
#  [-1.64447557 -0.43592758 -0.65314047  0.73368118  2.35398187 -0.65102212]
#  [-1.64447557 -0.43592758 -0.53849187  0.81860414  2.43889965 -0.6378352 ]
#  [-1.64447557 -0.43592758 -0.19454608  0.87121129  2.41235295 -0.61673612]
#  [-1.64447557 -0.43592758 -0.07989749  0.90277558  2.4852904  -0.56775613]
#  [-1.64447557 -0.43592758  0.03475111  1.04030569  2.5352172  -0.57566828]
#  [-1.64447557 -0.43592758  0.14939971  1.16731437  2.56128891 -0.53196306]
#  [-1.64447557 -0.43592758  0.2640483   1.13575008  2.6141712  -0.48411338]
#  [-1.64447557 -0.43592758  0.60799409  1.16205365  2.60736301 -0.47733153]
#  [-1.64447557 -0.43592758  0.72264269  1.19887866  2.61549062 -0.45962338]
#  [-1.64447557 -0.43592758  0.83729129  1.25749805  2.69623904 -0.45434861]
#  [-1.64447557 -0.43592758  0.95193988  1.2146608   2.62815704 -0.38050185]
#  [-1.64447557 -0.43592758  1.06658848  1.2146608   2.60614914 -0.42910508]
#  [-1.64447557 -0.43592758  1.52518287  1.23044294  2.67760885 -0.46414461]
#  [-1.64447557 -0.43592758  1.63983146  1.29432305  2.65053438 -0.48976491]
#  [-1.64447557 -0.43592758  1.75448006  1.40554959  2.7519185  -0.53799137]
#  [-1.64447557 -0.14204258 -1.68497784  1.69639196  2.84274727 -0.50634276]
#   -3.13407411e-01 -2.51270028e-01]
#  [ 1.75123116e+00 -4.35927584e-01  1.63983146e+00  1.10568885e+00
#   -2.89710654e-01 -1.67250503e-01]
#  [ 1.75123116e+00 -4.35927584e-01  1.75448006e+00  1.02903273e+00
#   -3.42856833e-01 -1.73278810e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -1.68497784e+00  1.10268273e+00
#   -2.54772452e-01 -2.12839573e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -1.34103205e+00  1.24096437e+00
#   -1.92548674e-01 -2.65964026e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -1.22638345e+00  1.22142458e+00
#   -2.26273011e-01 -2.64833719e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -1.11173486e+00  1.24697662e+00
#   -1.70751879e-01 -2.71238794e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -9.97086259e-01  1.28455315e+00
#   -1.51013378e-01 -1.95131422e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -8.82437662e-01  1.24096437e+00
#   -1.94659743e-01 -2.24896186e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -5.38491872e-01  1.35369397e+00
#   -1.14439097e-01 -2.24896186e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -4.23843276e-01  1.37173071e+00
#   -1.05942041e-01 -2.45241722e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -3.09194679e-01  1.35369397e+00
#   -1.14016883e-01 -2.13969880e-01]
#  [ 1.75123116e+00 -1.42042582e-01 -1.94546082e-01  1.47093276e+00
#   -8.30897122e-02 -2.46372029e-01]]
# First expected output [ 1.25749805  2.35456241 -0.05685714]
# Last expected output [ 1.51001235 -0.1394025  -0.3420714 ]

# %% [markdown]
# Shuffle the packages and create training_set (75%) and test_set (25%)

# %%
#https://play.pixelblaster.ro/blog/2017/01/20/how-to-shuffle-two-arrays-to-the-same-order/
s = np.arange(X.shape[0])
np.random.shuffle(s)

shuffle_X = X[s]
shuffle_Y = Y[s]

test_set_size = int(shuffle_X.shape[0]*0.25)
print("Estimated test_set_size: %d" % test_set_size)

test_set_X = shuffle_X[0:test_set_size]
test_set_Y = shuffle_Y[0:test_set_size]
training_set_X = shuffle_X[test_set_size:]
training_set_Y = shuffle_Y[test_set_size:]

print("Training set shape: %s - %s - %s" % training_set_X.shape)
print("Test set shape: %s - %s - %s" % test_set_X.shape)
# Out:
# Estimated test_set_size: 642
# Training set shape: 1927 - 100 - 6
# Test set shape: 642 - 100 - 6

# %% [markdown]
# Create the LSTM model:

# %%
dropout = 0.1

opt = Adam(lr=0.005, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
rms = RMSprop(lr=0.008)

model = Sequential()
model.add(LSTM(128, input_shape=(package_size, number_features), dropout=dropout))
model.add(Dense(32))
model.add(Dense(16))
model.add(Dense(number_features - 3))

#Add loss function
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['accuracy'])

#Compile the model
history = model.fit(training_set_X, training_set_Y, epochs=100, batch_size=200, verbose=2)
# Out:
# Epoch 1/100
#  - 3s - loss: 0.2801 - acc: 0.8225
# Epoch 2/100
#  - 3s - loss: 0.1036 - acc: 0.9123
# Epoch 3/100
#  - 2s - loss: 0.0717 - acc: 0.9222
# Epoch 4/100
#  - 2s - loss: 0.0738 - acc: 0.9242
# Epoch 5/100
#  - 2s - loss: 0.0652 - acc: 0.9237
# Epoch 6/100
#  - 2s - loss: 0.0519 - acc: 0.9242
# Epoch 7/100
#  - 2s - loss: 0.0479 - acc: 0.9336
# Epoch 8/100
#  - 3s - loss: 0.0390 - acc: 0.9377
# Epoch 9/100
#  - 3s - loss: 0.0327 - acc: 0.9486
# Epoch 10/100
#  - 3s - loss: 0.0305 - acc: 0.9471
# Epoch 11/100
#  - 3s - loss: 0.0277 - acc: 0.9424
# Epoch 12/100
#  - 3s - loss: 0.0281 - acc: 0.9471
# Epoch 13/100
#  - 3s - loss: 0.0261 - acc: 0.9393
# Epoch 14/100
#  - 2s - loss: 0.0217 - acc: 0.9512
# Epoch 15/100
#  - 3s - loss: 0.0204 - acc: 0.9471
# Epoch 16/100
#  - 3s - loss: 0.0208 - acc: 0.9523
# Epoch 17/100
#  - 4s - loss: 0.0192 - acc: 0.9533
# Epoch 18/100
#  - 6s - loss: 0.0178 - acc: 0.9559
# Epoch 19/100
#  - 4s - loss: 0.0172 - acc: 0.9580
# Epoch 20/100
#  - 4s - loss: 0.0172 - acc: 0.9580
# Epoch 21/100
#  - 5s - loss: 0.0151 - acc: 0.9600
# Epoch 22/100
#  - 6s - loss: 0.0144 - acc: 0.9543
# Epoch 23/100
#  - 3s - loss: 0.0149 - acc: 0.9663
# Epoch 24/100
#  - 3s - loss: 0.0145 - acc: 0.9585
# Epoch 25/100
#  - 3s - loss: 0.0154 - acc: 0.9549
# Epoch 26/100
#  - 3s - loss: 0.0154 - acc: 0.9549
# Epoch 27/100
#  - 3s - loss: 0.0144 - acc: 0.9543
# Epoch 28/100
#  - 3s - loss: 0.0120 - acc: 0.9559
# Epoch 29/100
#  - 3s - loss: 0.0141 - acc: 0.9585
# Epoch 30/100
#  - 4s - loss: 0.0136 - acc: 0.9574
# Epoch 31/100
#  - 4s - loss: 0.0121 - acc: 0.9569
# Epoch 32/100
#  - 3s - loss: 0.0119 - acc: 0.9657
# Epoch 33/100
#  - 3s - loss: 0.0109 - acc: 0.9580
# Epoch 34/100
#  - 3s - loss: 0.0102 - acc: 0.9626
# Epoch 35/100
#  - 3s - loss: 0.0110 - acc: 0.9580
# Epoch 36/100
#  - 4s - loss: 0.0106 - acc: 0.9595
# Epoch 37/100
#  - 4s - loss: 0.0101 - acc: 0.9626
# Epoch 38/100
#  - 4s - loss: 0.0099 - acc: 0.9611
# Epoch 39/100
#  - 3s - loss: 0.0102 - acc: 0.9626
# Epoch 40/100
#  - 3s - loss: 0.0104 - acc: 0.9637
# Epoch 41/100
#  - 3s - loss: 0.0103 - acc: 0.9600
# Epoch 42/100
#  - 3s - loss: 0.0091 - acc: 0.9673
# Epoch 43/100
#  - 3s - loss: 0.0096 - acc: 0.9683
# Epoch 44/100
#  - 3s - loss: 0.0090 - acc: 0.9611
# Epoch 45/100
#  - 3s - loss: 0.0106 - acc: 0.9652
# Epoch 46/100
#  - 3s - loss: 0.0102 - acc: 0.9632
# Epoch 47/100
#  - 3s - loss: 0.0109 - acc: 0.9611
# Epoch 48/100
#  - 2s - loss: 0.0093 - acc: 0.9663
# Epoch 49/100
#  - 3s - loss: 0.0090 - acc: 0.9637
# Epoch 50/100
#  - 2s - loss: 0.0092 - acc: 0.9652
# Epoch 51/100
#  - 3s - loss: 0.0088 - acc: 0.9657
# Epoch 52/100
#  - 3s - loss: 0.0089 - acc: 0.9668
# Epoch 53/100
#  - 3s - loss: 0.0097 - acc: 0.9611
# Epoch 54/100
#  - 3s - loss: 0.0103 - acc: 0.9637
# Epoch 55/100
#  - 3s - loss: 0.0094 - acc: 0.9657
# Epoch 56/100
#  - 3s - loss: 0.0085 - acc: 0.9632
# Epoch 57/100
#  - 3s - loss: 0.0081 - acc: 0.9709
# Epoch 58/100
#  - 4s - loss: 0.0088 - acc: 0.9663
# Epoch 59/100
#  - 6s - loss: 0.0085 - acc: 0.9621
# Epoch 60/100
#  - 4s - loss: 0.0079 - acc: 0.9683
# Epoch 61/100
#  - 5s - loss: 0.0089 - acc: 0.9626
# Epoch 62/100
#  - 4s - loss: 0.0085 - acc: 0.9663
# Epoch 63/100
#  - 3s - loss: 0.0088 - acc: 0.9720
# Epoch 64/100
#  - 3s - loss: 0.0081 - acc: 0.9647
# Epoch 65/100
#  - 3s - loss: 0.0085 - acc: 0.9632
# Epoch 66/100
#  - 3s - loss: 0.0086 - acc: 0.9683
# Epoch 67/100
#  - 3s - loss: 0.0096 - acc: 0.9668
# Epoch 68/100
#  - 3s - loss: 0.0084 - acc: 0.9647
# Epoch 69/100
#  - 3s - loss: 0.0085 - acc: 0.9673
# Epoch 70/100
#  - 3s - loss: 0.0087 - acc: 0.9668
# Epoch 71/100
#  - 5s - loss: 0.0080 - acc: 0.9647
# Epoch 72/100
#  - 3s - loss: 0.0079 - acc: 0.9725
# Epoch 73/100
#  - 3s - loss: 0.0074 - acc: 0.9642
# Epoch 74/100
#  - 3s - loss: 0.0073 - acc: 0.9678
# Epoch 75/100
#  - 3s - loss: 0.0110 - acc: 0.9600
# Epoch 76/100
#  - 3s - loss: 0.0104 - acc: 0.9704
# Epoch 77/100
#  - 3s - loss: 0.0102 - acc: 0.9637
# Epoch 78/100
#  - 3s - loss: 0.0092 - acc: 0.9642
# Epoch 79/100
#  - 2s - loss: 0.0088 - acc: 0.9585
# Epoch 80/100
#  - 2s - loss: 0.0081 - acc: 0.9647
# Epoch 81/100
#  - 2s - loss: 0.0083 - acc: 0.9673
# Epoch 82/100
#  - 2s - loss: 0.0079 - acc: 0.9694
# Epoch 83/100
#  - 2s - loss: 0.0082 - acc: 0.9720
# Epoch 84/100
#  - 2s - loss: 0.0076 - acc: 0.9657
# Epoch 85/100
#  - 2s - loss: 0.0078 - acc: 0.9673
# Epoch 86/100
#  - 2s - loss: 0.0077 - acc: 0.9725
# Epoch 87/100
#  - 2s - loss: 0.0075 - acc: 0.9725
# Epoch 88/100
#  - 3s - loss: 0.0072 - acc: 0.9689
# Epoch 89/100
#  - 2s - loss: 0.0079 - acc: 0.9699
# Epoch 90/100
#  - 3s - loss: 0.0073 - acc: 0.9725
# Epoch 91/100
#  - 2s - loss: 0.0071 - acc: 0.9730
# Epoch 92/100
#  - 2s - loss: 0.0068 - acc: 0.9741
# Epoch 93/100
#  - 3s - loss: 0.0069 - acc: 0.9756
# Epoch 94/100
#  - 3s - loss: 0.0070 - acc: 0.9709
# Epoch 95/100
#  - 3s - loss: 0.0077 - acc: 0.9761
# Epoch 96/100
#  - 3s - loss: 0.0072 - acc: 0.9715
# Epoch 97/100
#  - 3s - loss: 0.0070 - acc: 0.9715
# Epoch 98/100
#  - 2s - loss: 0.0070 - acc: 0.9715
# Epoch 99/100
#  - 3s - loss: 0.0072 - acc: 0.9694
# Epoch 100/100
#  - 2s - loss: 0.0069 - acc: 0.9699

# %% [markdown]
# Evaluate the model

# %%
print("Training set performance")
print(model.evaluate(training_set_X, training_set_Y, batch_size = package_size))
print("Test set performance")
print(model.evaluate(test_set_X, test_set_Y, batch_size = package_size))
# Out:
# Training set performance
# 1927/1927 [==============================] - 1s 639us/step
# [0.011244799920029603, 0.9730150562899065]
# Test set performance
# 642/642 [==============================] - 0s 462us/step
# [0.012057448093231036, 0.978193157929869]

# %% [markdown]
# Plot the graphic of the neural network:

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
pyplot.plot(history.history['acc'])
pyplot.show()
# summarize history for loss
pyplot.plot(history.history['loss'])
pyplot.show()
# Out:
# dict_keys(['loss', 'acc'])

# %% [markdown]
# Now we are going to compare the predicted with the real values in the 100 last dates:

# %%
#Get 101 rows (it's hundred packages but not really :P)
last_hundred_packages = X[X.shape[0] - 101:]
last_package = last_hundred_packages[last_hundred_packages.shape[0] - 1]
last_package_row = last_package[last_package.shape[0] - 1]

print("last_hundred_packages shape: %s " % str(last_hundred_packages.shape))
print("last_package shape: %s" % str(last_package.shape))
print("last_package_row shape: %s" % str(last_package_row.shape))

print("\nMean in reg: %s" % str(mean))
print("Std in reg: %s" % str(std))

def denormalize(row):
    return row* std + mean


last_date_found = denormalize(last_package_row)

print("\nLast row found: %s" % str(denormalize(last_package_row)))
print("Last date found %s" % to_time(last_date_found))
# Out:
# last_hundred_packages shape: (101, 100, 6)
# last_package shape: (100, 6)
# last_package_row shape: (6,)
#
# Mean in reg: [2.01232709e+03 6.48332709e+00 1.56968902e+01 4.70275084e+00
#  1.01151362e+04 8.21590708e+01]
# Std in reg: [3.23938457e+00 3.40269151e+00 8.72230476e+00 1.33061770e+00
#  1.89477405e+03 2.65414497e+01]
#
# Last row found: [2.0180e+03 6.0000e+00 1.4000e+01 6.6600e+00 9.9577e+03 7.5620e+01]
# Last date found 2018-06-14

# %%
predicted = np.zeros((last_hundred_packages.shape[0] - 1, number_features))
print(predicted.shape)

for i in range(last_hundred_packages.shape[0] - 1):
    package = last_hundred_packages[i]
    next_package = last_hundred_packages[i+1]
    y_predicted =  model.predict(np.array([package]))
    date_predicted = next_package[next_package.shape[0] - 1][0:3]
    
    predicted[i] = np.append(date_predicted, y_predicted)
    
    print("Date prediction %s" % to_time(denormalize(next_package[next_package.shape[0] - 1])))
    
    
print("Last predicted row: %s" % str(denormalize(predicted[predicted.shape[0] - 1])))
last_predicted_date = to_time(denormalize(predicted[predicted.shape[0] - 1]))
print("Last predicted date %s" % last_predicted_date)
# Out:
# (100, 6)
# Date prediction 2018-01-17
# Date prediction 2018-01-18
# Date prediction 2018-01-19
# Date prediction 2018-01-22
# Date prediction 2018-01-23
# Date prediction 2018-01-24
# Date prediction 2018-01-25
# Date prediction 2018-01-26
# Date prediction 2018-01-29
# Date prediction 2018-01-30
# Date prediction 2018-01-31
# Date prediction 2018-02-01
# Date prediction 2018-02-02
# Date prediction 2018-02-05
# Date prediction 2018-02-06
# Date prediction 2018-02-07
# Date prediction 2018-02-08
# Date prediction 2018-02-09
# Date prediction 2018-02-12
# Date prediction 2018-02-13
# Date prediction 2018-02-14
# Date prediction 2018-02-15
# Date prediction 2018-02-16
# Date prediction 2018-02-20
# Date prediction 2018-02-21
# Date prediction 2018-02-22
# Date prediction 2018-02-23
# Date prediction 2018-02-26
# Date prediction 2018-02-27
# Date prediction 2018-02-28
# Date prediction 2018-03-02
# Date prediction 2018-03-05
# Date prediction 2018-03-06
# Date prediction 2018-03-07
# Date prediction 2018-03-08
# Date prediction 2018-03-09
# Date prediction 2018-03-12
# Date prediction 2018-03-13
# Date prediction 2018-03-14
# Date prediction 2018-03-15
# Date prediction 2018-03-16
# Date prediction 2018-03-19
# Date prediction 2018-03-20
# Date prediction 2018-03-21
# Date prediction 2018-03-22
# Date prediction 2018-03-23
# Date prediction 2018-03-26
# Date prediction 2018-03-27
# Date prediction 2018-03-28
# Date prediction 2018-03-29
# Date prediction 2018-04-03
# Date prediction 2018-04-04
# Date prediction 2018-04-05
# Date prediction 2018-04-06
# Date prediction 2018-04-09
# Date prediction 2018-04-10
# Date prediction 2018-04-11
# Date prediction 2018-04-12
# Date prediction 2018-04-13
# Date prediction 2018-04-16
# Date prediction 2018-04-17
# Date prediction 2018-04-18
# Date prediction 2018-04-19
# Date prediction 2018-04-23
# Date prediction 2018-04-24
# Date prediction 2018-04-25
# Date prediction 2018-04-26
# Date prediction 2018-04-27
# Date prediction 2018-04-30
# Date prediction 2018-05-02
# Date prediction 2018-05-03
# Date prediction 2018-05-04
# Date prediction 2018-05-07
# Date prediction 2018-05-08
# Date prediction 2018-05-09
# Date prediction 2018-05-10
# Date prediction 2018-05-11
# Date prediction 2018-05-14
# Date prediction 2018-05-15
# Date prediction 2018-05-16
# Date prediction 2018-05-17
# Date prediction 2018-05-18
# Date prediction 2018-05-21
# Date prediction 2018-05-22
# Date prediction 2018-05-23
# Date prediction 2018-05-24
# Date prediction 2018-05-25
# Date prediction 2018-05-29
# Date prediction 2018-05-30
# Date prediction 2018-05-31
# Date prediction 2018-06-01
# Date prediction 2018-06-04
# Date prediction 2018-06-05
# Date prediction 2018-06-06
# Date prediction 2018-06-07
# Date prediction 2018-06-08
# Date prediction 2018-06-11
# Date prediction 2018-06-12
# Date prediction 2018-06-13
# Date prediction 2018-06-14
# Last predicted row: [2.01800000e+03 6.00000000e+00 1.40000000e+01 6.36226315e+00
#  9.88895561e+03 7.62928713e+01]
# Last predicted date 2018-06-14

# %%
#Now plot the predicted vs the last_hundred_dates

last_package_denorm = np.zeros((last_package.shape))
predicted_denorm = np.zeros((predicted.shape))

for i in range(last_package.shape[0]):
    last_package_denorm[i] = denormalize(last_package[i])
    predicted_denorm[i] = denormalize(predicted[i])

pyplot.figure()
print(np.max(last_package_denorm[:,3]))
print(np.max(predicted_denorm[:,3]))

pyplot.plot(list(map(to_time, last_package_denorm[:,0:3])), last_package_denorm[:,3])
pyplot.plot(list(map(to_time, predicted_denorm[:,0:3])), predicted_denorm[:,3])

pyplot.show()
# Out:
# 6.754
# 6.489341251761991

# %% [markdown]
# Now generate the prediction for the next 100 days:

# %%
sampling_package = last_package
days_to_predict = 200
future_predictions = np.zeros((days_to_predict, number_features))

def next_day(day): 
    n_day = day + timedelta(days=1)
    while(n_day.weekday() > 4):
        n_day = n_day + timedelta(days=1)
    return n_day
    
next_day_generated = next_day(last_predicted_date)

for i in range(days_to_predict):
    print("\nGenerating for %s" % next_day_generated)
    predicted = model.predict(np.array([sampling_package]))
    
    #Generate the normalized date using an empty row  and changing the date
    
    fake_date_row = np.append([next_day_generated.year, next_day_generated.month, next_day_generated.day], np.zeros(number_features - 3))
    
    date_norm = (fake_date_row - mean)/std
    
    row = np.append(date_norm[0:3], predicted[0])

    future_predictions[i] = row
    
    print("Date generated: %s" % to_time(denormalize(future_predictions[i])))
    print("Inserted denormalized : %s" % str(denormalize(row)))
    
    sampling_package = np.concatenate((sampling_package[1:], np.array([row])))
    
    print("Shape of sampling_package: %s" % str(sampling_package.shape))
    print("First date found %s" % to_time(denormalize(sampling_package[0])))
    print("Last date found %s" % to_time(denormalize(sampling_package[sampling_package.shape[0] - 1])))
    
    next_day_generated = next_day(next_day_generated)
# Out:
# Generating for 2018-06-15
# Date generated: 2018-06-15
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 1.50000000e+01 6.44338497e+00
#  9.96677453e+03 7.59510785e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-18
# Last date found 2018-06-15
#
# Generating for 2018-06-18
# Date generated: 2018-06-18
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 1.80000000e+01 6.35597664e+00
#  9.88994657e+03 7.58772571e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-19
# Last date found 2018-06-18
#
# Generating for 2018-06-19
# Date generated: 2018-06-19
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 1.90000000e+01 6.26895567e+00
#  9.81121706e+03 7.58393169e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-22
# Last date found 2018-06-19
#
# Generating for 2018-06-20
# Date generated: 2018-06-20
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.00000000e+01 6.19214360e+00
#  9.73544455e+03 7.58553900e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-23
# Last date found 2018-06-20
#
# Generating for 2018-06-21
# Date generated: 2018-06-21
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.10000000e+01 6.12489628e+00
#  9.66505986e+03 7.58945332e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-24
# Last date found 2018-06-21
#
# Generating for 2018-06-22
# Date generated: 2018-06-22
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.20000000e+01 6.06841417e+00
#  9.60256924e+03 7.59382746e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-25
# Last date found 2018-06-22
#
# Generating for 2018-06-25
# Date generated: 2018-06-25
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.50000000e+01 6.02197377e+00
#  9.54870812e+03 7.59763856e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-26
# Last date found 2018-06-25
#
# Generating for 2018-06-26
# Date generated: 2018-06-26
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.60000000e+01 5.98101749e+00
#  9.50300752e+03 7.59994273e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-29
# Last date found 2018-06-26
#
# Generating for 2018-06-27
# Date generated: 2018-06-27
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.70000000e+01 5.94983463e+00
#  9.46275428e+03 7.60169740e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-30
# Last date found 2018-06-27
#
# Generating for 2018-06-28
# Date generated: 2018-06-28
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.80000000e+01 5.92414564e+00
#  9.42746735e+03 7.60176511e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-01-31
# Last date found 2018-06-28
#
# Generating for 2018-06-29
# Date generated: 2018-06-29
# Inserted denormalized : [2.01800000e+03 6.00000000e+00 2.90000000e+01 5.90313156e+00
#  9.39600623e+03 7.60042659e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-01
# Last date found 2018-06-29
#
# Generating for 2018-07-02
# Date generated: 2018-07-02
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 2.00000000e+00 5.88556608e+00
#  9.36716079e+03 7.59847852e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-02
# Last date found 2018-07-02
#
# Generating for 2018-07-03
# Date generated: 2018-07-03
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 3.00000000e+00 5.91261271e+00
#  9.34061668e+03 7.61406535e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-05
# Last date found 2018-07-03
#
# Generating for 2018-07-04
# Date generated: 2018-07-04
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 4.00000000e+00 5.93973834e+00
#  9.37414647e+03 7.61187729e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-06
# Last date found 2018-07-04
#
# Generating for 2018-07-05
# Date generated: 2018-07-05
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 5.00000000e+00 5.97387863e+00
#  9.42763077e+03 7.61349180e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-07
# Last date found 2018-07-05
#
# Generating for 2018-07-06
# Date generated: 2018-07-06
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 6.00000000e+00 6.00380537e+00
#  9.48784343e+03 7.62697624e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-08
# Last date found 2018-07-06
#
# Generating for 2018-07-09
# Date generated: 2018-07-09
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 9.00000000e+00 6.02800045e+00
#  9.54486170e+03 7.64459573e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-09
# Last date found 2018-07-09
#
# Generating for 2018-07-10
# Date generated: 2018-07-10
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 1.00000000e+01 6.03888272e+00
#  9.58629305e+03 7.66108624e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-12
# Last date found 2018-07-10
#
# Generating for 2018-07-11
# Date generated: 2018-07-11
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 1.10000000e+01 6.04623389e+00
#  9.61666715e+03 7.67328202e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-13
# Last date found 2018-07-11
#
# Generating for 2018-07-12
# Date generated: 2018-07-12
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 1.20000000e+01 6.04892555e+00
#  9.63558099e+03 7.67962250e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02-14
# Last date found 2018-07-12
#
# Generating for 2018-07-13
# Date generated: 2018-07-13
# Inserted denormalized : [2.01800000e+03 7.00000000e+00 1.30000000e+01 6.04818415e+00
#  9.64474995e+03 7.68003097e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-02
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 9.00000000e+00 6.00795357e+00
#  9.52442343e+03 7.05319362e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-16
# Last date found 2018-08-09
#
# Generating for 2018-08-10
# Date generated: 2018-08-10
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 1.00000000e+01 5.99828358e+00
#  9.54073757e+03 7.00767966e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-19
# Last date found 2018-08-10
#
# Generating for 2018-08-13
# Date generated: 2018-08-13
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 1.30000000e+01 5.98593446e+00
#  9.54915157e+03 6.96521262e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-20
# Last date found 2018-08-13
#
# Generating for 2018-08-14
# Date generated: 2018-08-14
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 1.40000000e+01 5.97025341e+00
#  9.54805297e+03 6.93044024e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-21
# Last date found 2018-08-14
#
# Generating for 2018-08-15
# Date generated: 2018-08-15
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 1.50000000e+01 5.95583023e+00
#  9.54212263e+03 6.89880211e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-22
# Last date found 2018-08-15
#
# Generating for 2018-08-16
# Date generated: 2018-08-16
# Inserted denormalized : [2.0180000e+03 8.0000000e+00 1.6000000e+01 5.9433903e+00 9.5340628e+03
#  6.8699573e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-23
# Last date found 2018-08-16
#
# Generating for 2018-08-17
# Date generated: 2018-08-17
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 1.70000000e+01 5.93279117e+00
#  9.52515832e+03 6.84425686e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-26
# Last date found 2018-08-17
#
# Generating for 2018-08-20
# Date generated: 2018-08-20
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.00000000e+01 5.92405951e+00
#  9.51603004e+03 6.82256188e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-27
# Last date found 2018-08-20
#
# Generating for 2018-08-21
# Date generated: 2018-08-21
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.10000000e+01 5.91609502e+00
#  9.50564574e+03 6.80921206e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-28
# Last date found 2018-08-21
#
# Generating for 2018-08-22
# Date generated: 2018-08-22
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.20000000e+01 5.90925215e+00
#  9.49307581e+03 6.79842160e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-03-29
# Last date found 2018-08-22
#
# Generating for 2018-08-23
# Date generated: 2018-08-23
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.30000000e+01 5.90358292e+00
#  9.47972284e+03 6.78886541e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-03
# Last date found 2018-08-23
#
# Generating for 2018-08-24
# Date generated: 2018-08-24
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.40000000e+01 5.89896757e+00
#  9.46568890e+03 6.78091953e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-04
# Last date found 2018-08-24
#
# Generating for 2018-08-27
# Date generated: 2018-08-27
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.70000000e+01 5.89516390e+00
#  9.45089660e+03 6.77502977e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-05
# Last date found 2018-08-27
#
# Generating for 2018-08-28
# Date generated: 2018-08-28
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.80000000e+01 5.89311014e+00
#  9.43732130e+03 6.77539363e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-06
# Last date found 2018-08-28
#
# Generating for 2018-08-29
# Date generated: 2018-08-29
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 2.90000000e+01 5.89034567e+00
#  9.41931130e+03 6.77776978e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-09
# Last date found 2018-08-29
#
# Generating for 2018-08-30
# Date generated: 2018-08-30
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 3.00000000e+01 5.88784349e+00
#  9.39915424e+03 6.78169281e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-10
# Last date found 2018-08-30
#
# Generating for 2018-08-31
# Date generated: 2018-08-31
# Inserted denormalized : [2.01800000e+03 8.00000000e+00 3.10000000e+01 5.88556901e+00
#  9.37686279e+03 6.78765408e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-11
# Last date found 2018-08-31
#
# Generating for 2018-09-03
# Date generated: 2018-09-03
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 3.00000000e+00 5.88340303e+00
#  9.35247250e+03 6.79633511e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-12
# Last date found 2018-09-03
#
# Generating for 2018-09-04
# Date generated: 2018-09-04
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 4.00000000e+00 5.86261474e+00
#  9.28959984e+03 6.76497035e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-13
# Last date found 2018-09-04
#
# Generating for 2018-09-05
# Date generated: 2018-09-05
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 5.00000000e+00 5.88585977e+00
#  9.31377486e+03 6.73226911e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-16
# Last date found 2018-09-05
#
# Generating for 2018-09-06
# Date generated: 2018-09-06
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 6.00000000e+00 5.90951847e+00
#  9.35822485e+03 6.71124204e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-17
# Last date found 2018-09-06
#
# Generating for 2018-09-07
# Date generated: 2018-09-07
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 7.00000000e+00 5.92786398e+00
#  9.40730561e+03 6.70124258e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-18
# Last date found 2018-09-07
#
# Generating for 2018-09-10
# Date generated: 2018-09-10
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.00000000e+01 5.94015322e+00
#  9.45277367e+03 6.69438875e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-19
# Last date found 2018-09-10
#
# Generating for 2018-09-11
# Date generated: 2018-09-11
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.10000000e+01 5.94495677e+00
#  9.48634746e+03 6.69070065e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-23
# Last date found 2018-09-11
#
# Generating for 2018-09-12
# Date generated: 2018-09-12
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.20000000e+01 5.94508414e+00
#  9.50968782e+03 6.68365239e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-24
# Last date found 2018-09-12
#
# Generating for 2018-09-13
# Date generated: 2018-09-13
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.30000000e+01 5.94301888e+00
#  9.52498744e+03 6.67373092e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-25
# Last date found 2018-09-13
#
# Generating for 2018-09-14
# Date generated: 2018-09-14
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.40000000e+01 5.93953776e+00
#  9.53388385e+03 6.66226621e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-26
# Last date found 2018-09-14
#
# Generating for 2018-09-17
# Date generated: 2018-09-17
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.70000000e+01 5.93531398e+00
#  9.53774727e+03 6.65057654e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-27
# Last date found 2018-09-17
#
# Generating for 2018-09-18
# Date generated: 2018-09-18
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.80000000e+01 5.93024355e+00
#  9.53594281e+03 6.64524506e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-04-30
# Last date found 2018-09-18
#
# Generating for 2018-09-19
# Date generated: 2018-09-19
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 1.90000000e+01 5.92508659e+00
#  9.52963402e+03 6.64067057e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-02
# Last date found 2018-09-19
#
# Generating for 2018-09-20
# Date generated: 2018-09-20
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 2.00000000e+01 5.92093228e+00
#  9.52136774e+03 6.63716946e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-03
# Last date found 2018-09-20
#
# Generating for 2018-09-21
# Date generated: 2018-09-21
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 2.10000000e+01 5.91729936e+00
#  9.51143654e+03 6.63434813e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-04
# Last date found 2018-09-21
#
# Generating for 2018-09-24
# Date generated: 2018-09-24
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 2.40000000e+01 5.91425040e+00
#  9.50026151e+03 6.63318015e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-07
# Last date found 2018-09-24
#
# Generating for 2018-09-25
# Date generated: 2018-09-25
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 2.50000000e+01 5.91272280e+00
#  9.48944409e+03 6.63963531e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-08
# Last date found 2018-09-25
#
# Generating for 2018-09-26
# Date generated: 2018-09-26
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 2.60000000e+01 5.91051414e+00
#  9.47496558e+03 6.64804393e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-09
# Last date found 2018-09-26
#
# Generating for 2018-09-27
# Date generated: 2018-09-27
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 2.70000000e+01 5.90867413e+00
#  9.45904062e+03 6.65810050e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-10
# Last date found 2018-09-27
#
# Generating for 2018-09-28
# Date generated: 2018-09-28
# Inserted denormalized : [2.01800000e+03 9.00000000e+00 2.80000000e+01 5.90712384e+00
#  9.44189939e+03 6.67011005e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-11
# Last date found 2018-09-28
#
# Generating for 2018-10-01
# Date generated: 2018-10-01
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.00000000e+00 5.90565928e+00
#  9.42348140e+03 6.68448199e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-14
# Last date found 2018-10-01
#
# Generating for 2018-10-02
# Date generated: 2018-10-02
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 2.00000000e+00 5.88956827e+00
#  9.38212104e+03 6.63988353e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-15
# Last date found 2018-10-02
#
# Generating for 2018-10-03
# Date generated: 2018-10-03
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 3.00000000e+00 5.90887724e+00
#  9.41174461e+03 6.59452730e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-16
# Last date found 2018-10-03
#
# Generating for 2018-10-04
# Date generated: 2018-10-04
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 4.00000000e+00 5.92512743e+00
#  9.45266198e+03 6.55668237e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-17
# Last date found 2018-10-04
#
# Generating for 2018-10-05
# Date generated: 2018-10-05
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 5.00000000e+00 5.93429317e+00
#  9.49130388e+03 6.52636504e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-18
# Last date found 2018-10-05
#
# Generating for 2018-10-08
# Date generated: 2018-10-08
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 8.00000000e+00 5.93709879e+00
#  9.52246233e+03 6.49743655e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-21
# Last date found 2018-10-08
#
# Generating for 2018-10-09
# Date generated: 2018-10-09
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 9.00000000e+00 5.93361355e+00
#  9.54020851e+03 6.47305739e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-22
# Last date found 2018-10-09
#
# Generating for 2018-10-10
# Date generated: 2018-10-10
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.00000000e+01 5.92759472e+00
#  9.54980232e+03 6.44655615e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-23
# Last date found 2018-10-10
#
# Generating for 2018-10-11
# Date generated: 2018-10-11
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.10000000e+01 5.92101658e+00
#  9.55360842e+03 6.41891524e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-24
# Last date found 2018-10-11
#
# Generating for 2018-10-12
# Date generated: 2018-10-12
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.20000000e+01 5.91461468e+00
#  9.55375032e+03 6.39212639e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-25
# Last date found 2018-10-12
#
# Generating for 2018-10-15
# Date generated: 2018-10-15
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.50000000e+01 5.90871029e+00
#  9.55155465e+03 6.36750646e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-29
# Last date found 2018-10-15
#
# Generating for 2018-10-16
# Date generated: 2018-10-16
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.60000000e+01 5.90322388e+00
#  9.54567654e+03 6.35298898e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-30
# Last date found 2018-10-16
#
# Generating for 2018-10-17
# Date generated: 2018-10-17
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.70000000e+01 5.89873408e+00
#  9.53862383e+03 6.34162852e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-05-31
# Last date found 2018-10-17
#
# Generating for 2018-10-18
# Date generated: 2018-10-18
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.80000000e+01 5.89566300e+00
#  9.53170558e+03 6.33360449e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-01
# Last date found 2018-10-18
#
# Generating for 2018-10-19
# Date generated: 2018-10-19
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 1.90000000e+01 5.89376414e+00
#  9.52527538e+03 6.32929261e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-04
# Last date found 2018-10-19
#
# Generating for 2018-10-22
# Date generated: 2018-10-22
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 2.20000000e+01 5.89225723e+00
#  9.51858740e+03 6.32768135e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-05
# Last date found 2018-10-22
#
# Generating for 2018-10-23
# Date generated: 2018-10-23
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 2.30000000e+01 5.89230577e+00
#  9.51203940e+03 6.33607398e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-06
# Last date found 2018-10-23
#
# Generating for 2018-10-24
# Date generated: 2018-10-24
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 2.40000000e+01 5.89176772e+00
#  9.50317930e+03 6.34719097e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-07
# Last date found 2018-10-24
#
# Generating for 2018-10-25
# Date generated: 2018-10-25
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 2.50000000e+01 5.89136617e+00
#  9.49324121e+03 6.36075008e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-08
# Last date found 2018-10-25
#
# Generating for 2018-10-26
# Date generated: 2018-10-26
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 2.60000000e+01 5.89111229e+00
#  9.48229143e+03 6.37723066e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-11
# Last date found 2018-10-26
#
# Generating for 2018-10-29
# Date generated: 2018-10-29
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 2.90000000e+01 5.89072700e+00
#  9.47005743e+03 6.39663887e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-12
# Last date found 2018-10-29
#
# Generating for 2018-10-30
# Date generated: 2018-10-30
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 3.00000000e+01 5.89274943e+00
#  9.46043856e+03 6.42514307e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-13
# Last date found 2018-10-30
#
# Generating for 2018-10-31
# Date generated: 2018-10-31
# Inserted denormalized : [2.01800000e+03 1.00000000e+01 3.10000000e+01 5.89233115e+00
#  9.44600630e+03 6.45657302e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-14
# Last date found 2018-10-31
#
# Generating for 2018-11-01
# Date generated: 2018-11-01
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 1.00000000e+00 5.89104932e+00
#  9.42896682e+03 6.49143557e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-15
# Last date found 2018-11-01
#
# Generating for 2018-11-02
# Date generated: 2018-11-02
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.00000000e+00 5.85824510e+00
#  9.36641710e+03 6.45311763e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-18
# Last date found 2018-11-02
#
# Generating for 2018-11-05
# Date generated: 2018-11-05
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 5.00000000e+00 5.86928004e+00
#  9.37702118e+03 6.41216076e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-19
# Last date found 2018-11-05
#
# Generating for 2018-11-06
# Date generated: 2018-11-06
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 6.00000000e+00 5.87963869e+00
#  9.39887568e+03 6.37499641e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-20
# Last date found 2018-11-06
#
# Generating for 2018-11-07
# Date generated: 2018-11-07
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 7.00000000e+00 5.88410517e+00
#  9.42055000e+03 6.34116057e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-21
# Last date found 2018-11-07
#
# Generating for 2018-11-08
# Date generated: 2018-11-08
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 8.00000000e+00 5.88485402e+00
#  9.43872856e+03 6.30702478e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-22
# Last date found 2018-11-08
#
# Generating for 2018-11-09
# Date generated: 2018-11-09
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 9.00000000e+00 5.88314622e+00
#  9.45269642e+03 6.27169554e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-25
# Last date found 2018-11-09
#
# Generating for 2018-11-12
# Date generated: 2018-11-12
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 1.20000000e+01 5.88006356e+00
#  9.46285655e+03 6.23665865e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-26
# Last date found 2018-11-12
#
# Generating for 2018-11-13
# Date generated: 2018-11-13
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 1.30000000e+01 5.87572612e+00
#  9.46717211e+03 6.21087010e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-27
# Last date found 2018-11-13
#
# Generating for 2018-11-14
# Date generated: 2018-11-14
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 1.40000000e+01 5.87168015e+00
#  9.46941691e+03 6.18878879e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-28
# Last date found 2018-11-14
#
# Generating for 2018-11-15
# Date generated: 2018-11-15
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 1.50000000e+01 5.86884891e+00
#  9.47106596e+03 6.17300650e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-06-29
# Last date found 2018-11-15
#
# Generating for 2018-11-16
# Date generated: 2018-11-16
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 1.60000000e+01 5.86743106e+00
#  9.47322860e+03 6.16547289e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-02
# Last date found 2018-11-16
#
# Generating for 2018-11-19
# Date generated: 2018-11-19
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 1.90000000e+01 5.86742575e+00
#  9.47631580e+03 6.16755638e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-03
# Last date found 2018-11-19
#
# Generating for 2018-11-20
# Date generated: 2018-11-20
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.00000000e+01 5.86846536e+00
#  9.47921208e+03 6.18504010e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-04
# Last date found 2018-11-20
#
# Generating for 2018-11-21
# Date generated: 2018-11-21
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.10000000e+01 5.87014873e+00
#  9.48179834e+03 6.21149594e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-05
# Last date found 2018-11-21
#
# Generating for 2018-11-22
# Date generated: 2018-11-22
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.20000000e+01 5.87256137e+00
#  9.48449020e+03 6.24741336e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-06
# Last date found 2018-11-22
#
# Generating for 2018-11-23
# Date generated: 2018-11-23
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.30000000e+01 5.87560898e+00
#  9.48725677e+03 6.29211244e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-09
# Last date found 2018-11-23
#
# Generating for 2018-11-26
# Date generated: 2018-11-26
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.60000000e+01 5.87903513e+00
#  9.48979176e+03 6.34510495e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-10
# Last date found 2018-11-26
#
# Generating for 2018-11-27
# Date generated: 2018-11-27
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.70000000e+01 5.88340493e+00
#  9.49391573e+03 6.41098075e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-11
# Last date found 2018-11-27
#
# Generating for 2018-11-28
# Date generated: 2018-11-28
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.80000000e+01 5.88691206e+00
#  9.49560408e+03 6.48234654e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-12
# Last date found 2018-11-28
#
# Generating for 2018-11-29
# Date generated: 2018-11-29
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 2.90000000e+01 5.88955169e+00
#  9.49557094e+03 6.55887564e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-13
# Last date found 2018-11-29
#
# Generating for 2018-11-30
# Date generated: 2018-11-30
# Inserted denormalized : [2.01800000e+03 1.10000000e+01 3.00000000e+01 5.89157912e+00
#  9.49404052e+03 6.63881711e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-16
# Last date found 2018-11-30
#
# Generating for 2018-12-03
# Date generated: 2018-12-03
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 3.00000000e+00 5.89300862e+00
#  9.49123550e+03 6.72143578e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-17
# Last date found 2018-12-03
#
# Generating for 2018-12-04
# Date generated: 2018-12-04
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 4.00000000e+00 5.89475378e+00
#  9.46078110e+03 6.76362929e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-18
# Last date found 2018-12-04
#
# Generating for 2018-12-05
# Date generated: 2018-12-05
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 5.00000000e+00 5.91734274e+00
#  9.48147958e+03 6.80835114e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-19
# Last date found 2018-12-05
#
# Generating for 2018-12-06
# Date generated: 2018-12-06
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 6.00000000e+00 5.94556937e+00
#  9.51758440e+03 6.83477503e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-20
# Last date found 2018-12-06
#
# Generating for 2018-12-07
# Date generated: 2018-12-07
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 7.00000000e+00 5.96985265e+00
#  9.55563355e+03 6.85716799e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-23
# Last date found 2018-12-07
#
# Generating for 2018-12-10
# Date generated: 2018-12-10
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.00000000e+01 5.98939749e+00
#  9.58965327e+03 6.87379095e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-24
# Last date found 2018-12-10
#
# Generating for 2018-12-11
# Date generated: 2018-12-11
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.10000000e+01 6.00050825e+00
#  9.61357103e+03 6.88896005e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-25
# Last date found 2018-12-11
#
# Generating for 2018-12-12
# Date generated: 2018-12-12
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.20000000e+01 6.01062405e+00
#  9.63290776e+03 6.89953030e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-26
# Last date found 2018-12-12
#
# Generating for 2018-12-13
# Date generated: 2018-12-13
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.30000000e+01 6.01908939e+00
#  9.64859696e+03 6.90916148e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-27
# Last date found 2018-12-13
#
# Generating for 2018-12-14
# Date generated: 2018-12-14
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.40000000e+01 6.02677811e+00
#  9.66240050e+03 6.91958998e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-30
# Last date found 2018-12-14
#
# Generating for 2018-12-17
# Date generated: 2018-12-17
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.70000000e+01 6.03393133e+00
#  9.67521821e+03 6.93241172e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-07-31
# Last date found 2018-12-17
#
# Generating for 2018-12-18
# Date generated: 2018-12-18
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.80000000e+01 6.03711916e+00
#  9.68519628e+03 6.95227049e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-01
# Last date found 2018-12-18
#
# Generating for 2018-12-19
# Date generated: 2018-12-19
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 1.90000000e+01 6.04195475e+00
#  9.69485587e+03 6.97469287e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-02
# Last date found 2018-12-19
#
# Generating for 2018-12-20
# Date generated: 2018-12-20
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 2.00000000e+01 6.04638284e+00
#  9.70405628e+03 7.00018370e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-03
# Last date found 2018-12-20
#
# Generating for 2018-12-21
# Date generated: 2018-12-21
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 2.10000000e+01 6.05081918e+00
#  9.71307127e+03 7.02820120e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-06
# Last date found 2018-12-21
#
# Generating for 2018-12-24
# Date generated: 2018-12-24
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 2.40000000e+01 6.05491337e+00
#  9.72148790e+03 7.05817247e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-07
# Last date found 2018-12-24
#
# Generating for 2018-12-25
# Date generated: 2018-12-25
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 2.50000000e+01 6.05566540e+00
#  9.72877086e+03 7.09161067e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-08
# Last date found 2018-12-25
#
# Generating for 2018-12-26
# Date generated: 2018-12-26
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 2.60000000e+01 6.05707555e+00
#  9.73356372e+03 7.12582121e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-09
# Last date found 2018-12-26
#
# Generating for 2018-12-27
# Date generated: 2018-12-27
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 2.70000000e+01 6.05748162e+00
#  9.73674141e+03 7.16158890e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-10
# Last date found 2018-12-27
#
# Generating for 2018-12-28
# Date generated: 2018-12-28
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 2.80000000e+01 6.05730333e+00
#  9.73854562e+03 7.19806105e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-13
# Last date found 2018-12-28
#
# Generating for 2018-12-31
# Date generated: 2018-12-31
# Inserted denormalized : [2.01800000e+03 1.20000000e+01 3.10000000e+01 6.05640363e+00
#  9.73891814e+03 7.23527088e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-14
# Last date found 2018-12-31
#
# Generating for 2019-01-01
# Date generated: 2019-01-01
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.00000000e+00 6.05322357e+00
#  9.74098255e+03 7.27418002e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-15
# Last date found 2019-01-01
#
# Generating for 2019-01-02
# Date generated: 2019-01-02
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.00000000e+00 6.16459667e+00
#  9.86029737e+03 7.30450423e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-16
# Last date found 2019-01-02
#
# Generating for 2019-01-03
# Date generated: 2019-01-03
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 3.00000000e+00 6.24635965e+00
#  9.97603702e+03 7.35976809e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-17
# Last date found 2019-01-03
#
# Generating for 2019-01-04
# Date generated: 2019-01-04
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 4.00000000e+00 6.28239253e+00
#  1.00567496e+04 7.43256021e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-20
# Last date found 2019-01-04
#
# Generating for 2019-01-07
# Date generated: 2019-01-07
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 7.00000000e+00 6.28074112e+00
#  1.01060177e+04 7.52144856e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-21
# Last date found 2019-01-07
#
# Generating for 2019-01-08
# Date generated: 2019-01-08
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 8.00000000e+00 6.24847979e+00
#  1.01230292e+04 7.60713693e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-22
# Last date found 2019-01-08
#
# Generating for 2019-01-09
# Date generated: 2019-01-09
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 9.00000000e+00 6.20768776e+00
#  1.01211407e+04 7.68978977e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-23
# Last date found 2019-01-09
#
# Generating for 2019-01-10
# Date generated: 2019-01-10
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.00000000e+01 6.16232235e+00
#  1.01043465e+04 7.76493570e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-24
# Last date found 2019-01-10
#
# Generating for 2019-01-11
# Date generated: 2019-01-11
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.10000000e+01 6.11682131e+00
#  1.00768128e+04 7.83275070e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-27
# Last date found 2019-01-11
#
# Generating for 2019-01-14
# Date generated: 2019-01-14
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.40000000e+01 6.07323358e+00
#  1.00416379e+04 7.89398355e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-28
# Last date found 2019-01-14
#
# Generating for 2019-01-15
# Date generated: 2019-01-15
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.50000000e+01 6.02560146e+00
#  9.99582041e+03 7.94743896e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-29
# Last date found 2019-01-15
#
# Generating for 2019-01-16
# Date generated: 2019-01-16
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.60000000e+01 5.98529228e+00
#  9.94630927e+03 7.99659929e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-30
# Last date found 2019-01-16
#
# Generating for 2019-01-17
# Date generated: 2019-01-17
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.70000000e+01 5.94763090e+00
#  9.89314786e+03 8.03721471e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-08-31
# Last date found 2019-01-17
#
# Generating for 2019-01-18
# Date generated: 2019-01-18
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 1.80000000e+01 5.91297120e+00
#  9.83834554e+03 8.06901667e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-03
# Last date found 2019-01-18
#
# Generating for 2019-01-21
# Date generated: 2019-01-21
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.10000000e+01 5.88085215e+00
#  9.78333668e+03 8.09180727e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-04
# Last date found 2019-01-21
#
# Generating for 2019-01-22
# Date generated: 2019-01-22
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.20000000e+01 5.84555566e+00
#  9.72565842e+03 8.10212147e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-05
# Last date found 2019-01-22
#
# Generating for 2019-01-23
# Date generated: 2019-01-23
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.30000000e+01 5.81606998e+00
#  9.66827205e+03 8.10589534e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-06
# Last date found 2019-01-23
#
# Generating for 2019-01-24
# Date generated: 2019-01-24
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.40000000e+01 5.78806027e+00
#  9.61219505e+03 8.09868036e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-07
# Last date found 2019-01-24
#
# Generating for 2019-01-25
# Date generated: 2019-01-25
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.50000000e+01 5.76217530e+00
#  9.55853593e+03 8.08123805e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-10
# Last date found 2019-01-25
#
# Generating for 2019-01-28
# Date generated: 2019-01-28
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.80000000e+01 5.73824773e+00
#  9.50787105e+03 8.05472862e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-11
# Last date found 2019-01-28
#
# Generating for 2019-01-29
# Date generated: 2019-01-29
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 2.90000000e+01 5.71304698e+00
#  9.45967380e+03 8.01505335e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-12
# Last date found 2019-01-29
#
# Generating for 2019-01-30
# Date generated: 2019-01-30
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 3.00000000e+01 5.69264843e+00
#  9.41155234e+03 7.97267779e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-13
# Last date found 2019-01-30
#
# Generating for 2019-01-31
# Date generated: 2019-01-31
# Inserted denormalized : [2.01900000e+03 1.00000000e+00 3.10000000e+01 5.67382285e+00
#  9.36541105e+03 7.92446204e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-14
# Last date found 2019-01-31
#
# Generating for 2019-02-01
# Date generated: 2019-02-01
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.00000000e+00 5.65711052e+00
#  9.32130648e+03 7.87200839e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-17
# Last date found 2019-02-01
#
# Generating for 2019-02-04
# Date generated: 2019-02-04
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 4.00000000e+00 5.69414859e+00
#  9.28543256e+03 7.91175863e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-18
# Last date found 2019-02-04
#
# Generating for 2019-02-05
# Date generated: 2019-02-05
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 5.00000000e+00 5.71751036e+00
#  9.31398826e+03 7.87181476e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-19
# Last date found 2019-02-05
#
# Generating for 2019-02-06
# Date generated: 2019-02-06
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 6.00000000e+00 5.74711256e+00
#  9.35676062e+03 7.84386773e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-20
# Last date found 2019-02-06
#
# Generating for 2019-02-07
# Date generated: 2019-02-07
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 7.00000000e+00 5.77195125e+00
#  9.40997635e+03 7.83381970e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-21
# Last date found 2019-02-07
#
# Generating for 2019-02-08
# Date generated: 2019-02-08
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 8.00000000e+00 5.79290569e+00
#  9.46651397e+03 7.83521944e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-24
# Last date found 2019-02-08
#
# Generating for 2019-02-11
# Date generated: 2019-02-11
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.10000000e+01 5.80978950e+00
#  9.52116722e+03 7.84380939e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-25
# Last date found 2019-02-11
#
# Generating for 2019-02-12
# Date generated: 2019-02-12
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.20000000e+01 5.81573314e+00
#  9.56368282e+03 7.85328569e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-26
# Last date found 2019-02-12
#
# Generating for 2019-02-13
# Date generated: 2019-02-13
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.30000000e+01 5.81981457e+00
#  9.59666933e+03 7.86669440e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-27
# Last date found 2019-02-13
#
# Generating for 2019-02-14
# Date generated: 2019-02-14
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.40000000e+01 5.82067937e+00
#  9.61921761e+03 7.87925392e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-09-28
# Last date found 2019-02-14
#
# Generating for 2019-02-15
# Date generated: 2019-02-15
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.50000000e+01 5.81900409e+00
#  9.63175524e+03 7.88984715e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-01
# Last date found 2019-02-15
#
# Generating for 2019-02-18
# Date generated: 2019-02-18
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.80000000e+01 5.81512253e+00
#  9.63526934e+03 7.89790100e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-02
# Last date found 2019-02-18
#
# Generating for 2019-02-19
# Date generated: 2019-02-19
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 1.90000000e+01 5.80377717e+00
#  9.62638439e+03 7.89902568e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-03
# Last date found 2019-02-19
#
# Generating for 2019-02-20
# Date generated: 2019-02-20
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 2.00000000e+01 5.79342772e+00
#  9.60922017e+03 7.89796278e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-04
# Last date found 2019-02-20
#
# Generating for 2019-02-21
# Date generated: 2019-02-21
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 2.10000000e+01 5.78199187e+00
#  9.58572136e+03 7.89055525e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-05
# Last date found 2019-02-21
#
# Generating for 2019-02-22
# Date generated: 2019-02-22
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 2.20000000e+01 5.77006706e+00
#  9.55752164e+03 7.87641163e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-08
# Last date found 2019-02-22
#
# Generating for 2019-02-25
# Date generated: 2019-02-25
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 2.50000000e+01 5.75779939e+00
#  9.52608062e+03 7.85574633e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-09
# Last date found 2019-02-25
#
# Generating for 2019-02-26
# Date generated: 2019-02-26
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 2.60000000e+01 5.74198899e+00
#  9.49110658e+03 7.82456598e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-10
# Last date found 2019-02-26
#
# Generating for 2019-02-27
# Date generated: 2019-02-27
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 2.70000000e+01 5.72850017e+00
#  9.45218606e+03 7.78997356e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-11
# Last date found 2019-02-27
#
# Generating for 2019-02-28
# Date generated: 2019-02-28
# Inserted denormalized : [2.01900000e+03 2.00000000e+00 2.80000000e+01 5.71531075e+00
#  9.41180520e+03 7.74885042e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-12
# Last date found 2019-02-28
#
# Generating for 2019-03-01
# Date generated: 2019-03-01
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.00000000e+00 5.70291611e+00
#  9.37070431e+03 7.70180663e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-15
# Last date found 2019-03-01
#
# Generating for 2019-03-04
# Date generated: 2019-03-04
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 4.00000000e+00 5.73424125e+00
#  9.33443336e+03 7.71199171e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-16
# Last date found 2019-03-04
#
# Generating for 2019-03-05
# Date generated: 2019-03-05
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 5.00000000e+00 5.75831166e+00
#  9.35506086e+03 7.66407458e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-17
# Last date found 2019-03-05
#
# Generating for 2019-03-06
# Date generated: 2019-03-06
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 6.00000000e+00 5.78453854e+00
#  9.38866474e+03 7.62476208e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-18
# Last date found 2019-03-06
#
# Generating for 2019-03-07
# Date generated: 2019-03-07
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 7.00000000e+00 5.80486579e+00
#  9.43021563e+03 7.59686465e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-19
# Last date found 2019-03-07
#
# Generating for 2019-03-08
# Date generated: 2019-03-08
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 8.00000000e+00 5.81929484e+00
#  9.47235938e+03 7.57472117e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-22
# Last date found 2019-03-08
#
# Generating for 2019-03-11
# Date generated: 2019-03-11
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.10000000e+01 5.82788240e+00
#  9.51036048e+03 7.55508301e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-23
# Last date found 2019-03-11
#
# Generating for 2019-03-12
# Date generated: 2019-03-12
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.20000000e+01 5.82629134e+00
#  9.53620726e+03 7.53516381e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-24
# Last date found 2019-03-12
#
# Generating for 2019-03-13
# Date generated: 2019-03-13
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.30000000e+01 5.82130276e+00
#  9.55177104e+03 7.51626270e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-25
# Last date found 2019-03-13
#
# Generating for 2019-03-14
# Date generated: 2019-03-14
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.40000000e+01 5.81370730e+00
#  9.55819170e+03 7.49499865e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-26
# Last date found 2019-03-14
#
# Generating for 2019-03-15
# Date generated: 2019-03-15
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.50000000e+01 5.80451183e+00
#  9.55670996e+03 7.47177886e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-29
# Last date found 2019-03-15
#
# Generating for 2019-03-18
# Date generated: 2019-03-18
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.80000000e+01 5.79444885e+00
#  9.54882874e+03 7.44738207e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-30
# Last date found 2019-03-18
#
# Generating for 2019-03-19
# Date generated: 2019-03-19
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 1.90000000e+01 5.78148277e+00
#  9.53334921e+03 7.42296629e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-10-31
# Last date found 2019-03-19
#
# Generating for 2019-03-20
# Date generated: 2019-03-20
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 2.00000000e+01 5.76955083e+00
#  9.51179032e+03 7.40055276e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-11-01
# Last date found 2019-03-20
#
# Generating for 2019-03-21
# Date generated: 2019-03-21
# Inserted denormalized : [2.01900000e+03 3.00000000e+00 2.10000000e+01 5.75856609e+00
#  9.48712565e+03 7.37669875e+01]
# Shape of sampling_package: (100, 6)
# First date found 2018-11-02
# Last date found 2019-03-21

# %%
#Denormalize and plot
future_predictions_denorm = np.zeros((future_predictions.shape))

for i in range(future_predictions.shape[0]):
    future_predictions_denorm[i] = denormalize(future_predictions[i])
    
pyplot.figure()
print(np.max(future_predictions_denorm[:,3]))

pyplot.plot(list(map(to_time, future_predictions_denorm[:,0:3])), future_predictions_denorm[:,3])

pyplot.show()
# Out:
# 6.443384971469964
